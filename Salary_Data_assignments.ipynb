# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
salary=pd.read_csv("Salary_Data.csv")
salary
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
salary.corr()['Salary']
# Out:
# YearsExperience    0.978242
# Salary             1.000000
# Name: Salary, dtype: float64

# %%
y=salary.iloc[:,1:]
y
# Out:
#       Salary
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# 5    56642.0
# 6    60150.0
# 7    54445.0
# 8    64445.0
# 9    57189.0
# 10   63218.0
# 11   55794.0
# 12   56957.0
# 13   57081.0
# 14   61111.0
# 15   67938.0
# 16   66029.0
# 17   83088.0
# 18   81363.0
# 19   93940.0
# 20   91738.0
# 21   98273.0
# 22  101302.0
# 23  113812.0
# 24  109431.0
# 25  105582.0
# 26  116969.0
# 27  112635.0
# 28  122391.0
# 29  121872.0

# %%
x=salary.iloc[:,0:1]
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
plt.scatter(salary.Salary,salary.YearsExperience);plt.xlabel('salary');plt.ylabel("yearExperience")
# Out:
# Text(0, 0.5, 'yearExperience')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=lm.predict(x_test)
y_pred
# Out:
# array([[ 36143.62176044],
#        [ 34237.05465324],
#        [ 66648.69547576],
#        [ 59022.42704693],
#        [ 91434.06786946],
#        [ 80947.94877982],
#        [101920.1869591 ],
#        [ 52349.44217171],
#        [ 42816.60663567]])

# %%
from sklearn.metrics import r2_score
score=r2_score(y_pred,y_test)
score
# Out:
# 0.8778036096515927

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(np.sqrt(x),y,test_size=0.3,random_state=2)
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
y_pred=lm.predict(x_test)
y_pred
from sklearn.metrics import r2_score
score=r2_score(y_pred,y_test)
score
# Out:
# 0.8299385491153927

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split((x),np.sqrt(y),test_size=0.3,random_state=2)
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
y_pred=lm.predict(x_test)
y_pred
from sklearn.metrics import r2_score
score=r2_score(y_pred,y_test)
score
# Out:
# 0.879324569952741

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split((x),np.log(y),test_size=0.3,random_state=2)
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
y_pred=lm.predict(x_test)
y_pred
from sklearn.metrics import r2_score
score=r2_score(y_pred,y_test)
score
# Out:
# 0.8631186137556405

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(np.log(x),(y),test_size=0.3,random_state=2)
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
y_pred=lm.predict(x_test)
y_pred
from sklearn.metrics import r2_score
score=r2_score(y_pred,y_test)
score
# Out:
# 0.7140245962788239
